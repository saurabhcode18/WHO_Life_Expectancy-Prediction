# %%
import pandas as pd

# %%
pd.read_csv(r'C:\Users\saura\Saurabh\Desktop\ML\Life Expectancy Data.csv')
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
who = pd.read_csv(r'C:\Users\saura\Saurabh\Desktop\ML\Life Expectancy Data.csv')
who.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
who.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
who.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20,20))
df_num = who.select_dtypes(include=['float64', 'int64'])
corr = df_num.corr()
sns.heatmap(corr, 
            annot=True,  
            fmt=".2f", 
            cmap="coolwarm", 
            linewidths=0.5)
plt.show()

# %%
who.drop(columns={'Country','Status', 'Year','infant deaths','percentage expenditure', 'under-five deaths ','Population',' thinness 5-9 years'},inplace=True)

# %%
who
# Out:
#       Life expectancy   Adult Mortality  Alcohol  Hepatitis B  Measles   \
# 0                 65.0            263.0     0.01         65.0      1154
# 1                 59.9            271.0     0.01         62.0       492
# 2                 59.9            268.0     0.01         64.0       430
# 3                 59.5            272.0     0.01         67.0      2787
# 4                 59.2            275.0     0.01         68.0      3013
# ...                ...              ...      ...          ...       ...
# 2933              44.3            723.0     4.36         68.0        31
# 2934              44.5            715.0     4.06          7.0       998
# 2935              44.8             73.0     4.43         73.0       304
# 2936              45.3            686.0     1.72         76.0       529
# 2937              46.0            665.0     1.68         79.0      1483
#
#        BMI   Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# ...

# %%
who.isnull().sum()[who.isnull().sum()>0]
# Out:
# Life expectancy                     10
# Adult Mortality                     10
# Alcohol                            194
# Hepatitis B                        553
#  BMI                                34
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# GDP                                448
#  thinness  1-19 years               34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

imp = SimpleImputer(strategy='median')
who[:] = imp.fit_transform(who)

# %%
who.isnull().sum()[who.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
who.describe().T
# who.max()-who.min()
# Out:
#                                   count         mean           std       min  \
# Life expectancy                  2938.0    69.234717      9.509115  36.30000
# Adult Mortality                  2938.0   164.725664    124.086215   1.00000
# Alcohol                          2938.0     4.546875      3.921946   0.01000
# Hepatitis B                      2938.0    83.022124     22.996984   1.00000
# Measles                          2938.0  2419.592240  11467.272489   0.00000
#  BMI                             2938.0    38.381178     19.935375   1.00000
# Polio                            2938.0    82.617767     23.367166   3.00000
# Total expenditure                2938.0     5.924098      2.400770   0.37000
# Diphtheria                       2938.0    82.393125     23.655562   2.00000
#  HIV/AIDS                        2938.0     1.742103      5.077785   0.10000
# GDP                              2938.0  6611.523863  13296.603449   1.68135
# ...

# %%
x = who.iloc[:,1:]
y = who['Life expectancy ']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x[:] = scaler.fit_transform(x)
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_5584\2244912636.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.11038437 -0.16812371 -0.17353132 ... -0.18452098 -0.16489658
#  -0.08168914]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   x[:] = scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
r2 = r2_score(y_test,y_pred)
print("r2:",r2)
mse = mean_squared_error(y_test,y_pred)
print("mean_squared_error:",mse)
mae = mean_absolute_error(y_test,y_pred)
print("mean_absolute_error:",mae)
# Out:
# r2: 0.8093295631099431
# mean_squared_error: 16.524904406807934
# mean_absolute_error: 2.960600745362746

# %%
import numpy as np

x_new = np.array([[263.0, 0.01, 65.0, 1154, 19.1, 6.0, 8.16,
                   65.0, 0.1, 584.259210, 17.2, 0.479, 10.1]])

x_new_scaled = scaler.transform(x_new)

y_pred = model.predict(x_new_scaled)
y_pred
# Out:
# C:\Users\saura\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\saura\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([60.45128025])
